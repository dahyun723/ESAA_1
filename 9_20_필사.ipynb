# %% [markdown]
# <a href="https://colab.research.google.com/github/dahyun723/ESAA_1/blob/main/9_20_%ED%95%84%EC%82%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# %matplotlib inline

pd.options.mode.chained_assignment = None  # default='warn'

# %%
from subprocess import check_output
print(check_output(["dir", r"C:\Users\pc\Downloads\aisles.csv\aisles.csv/input"], shell=True).decode("utf8"))

print(check_output(["dir", r"C:\Users\pc\Downloads\departments.csv\departments.csv/input"], shell=True).decode("utf8"))

print(check_output(["dir", r"C:\Users\pc\Downloads\order_products__prior.csv\order_products__prior.csv/input"], shell=True).decode("utf8"))

print(check_output(["dir", r"C:\Users\pc\Downloads\order_products__train.csv\order_products__train.csv/input"], shell=True).decode("utf8"))

print(check_output(["dir", r"C:\Users\pc\Downloads\orders.csv\orders.csv/input"], shell=True).decode("utf8"))

print(check_output(["dir", r"C:\Users\pc\Downloads\products.csv\products.csv/input"], shell=True).decode("utf8"))

print(check_output(["dir", r"C:\Users\pc\Downloads\sample_submission.csv\sample_submission.csv/input"], shell=True).decode("utf8"))
# Out:
# sample_data
#
# sample_data
#
# sample_data
#
# sample_data
#
# sample_data
#
# sample_data
#
# sample_data

# %%
import pandas as pd

order_products_train_df = pd.read_csv("/content/order_products__train.csv")
order_products_prior_df = pd.read_csv("/content/order_products__prior.csv")
orders_df = pd.read_csv("/content/orders.csv")
products_df = pd.read_csv("/content/products.csv")
aisles_df = pd.re
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e8c10f513a99> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 order_products_train_df = pd.read_csv("/content/order_products__train.csv")
#       4 order_products_prior_df = pd.read_csv("/content/order_products__prior.csv")
#       5 orders_df = pd.read_csv("/content/orders.csv")
#
# ...

# %%
import os
print(os.listdir("/content"))
# Out:
# ['.config', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
order_products_train_df = pd.read_csv("/content/drive/MyDrive/ESAA/order_products__train.csv")

# %%
from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# %%
orders_df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
order_products_prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
order_products_train_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
plt.figure(figsize=(4, 3))
sns.barplot(x=cnt_srs.index, y=cnt_srs.values, alpha=0.8, color=color[1])
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Eval set type', fontsize=12)
plt.show()

# %%
def get_unique_count(x):
    return len(np.unique(x))

cnt_srs = orders_df.groupby("eval_set")["user_id"].aggregate(get_unique_count)
cnt_srs
# Out:
# eval_set
# prior    206209
# test      75000
# train    131209
# Name: user_id, dtype: int64

# %%
cnt_srs = orders_df.eval_set.value_counts()

plt.figure(figsize=(12,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[1])
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Eval set type', fontsize=12)
plt.title('Count of rows in each dataset', fontsize=15)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-42b06ad21152> in <cell line: 4>()
#       2
#       3 plt.figure(figsize=(12,8))
# ----> 4 sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[1])
#       5 plt.ylabel('Number of Occurrences', fontsize=12)
#       6 plt.xlabel('Eval set type', fontsize=12)
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# %matplotlib inline

pd.options.mode.chained_assignment = None  # default='warn'

# %%
cnt_srs = orders_df.eval_set.value_counts()

plt.figure(figsize=(12,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[1])
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Eval set type', fontsize=12)
plt.title('Count of rows in each dataset', fontsize=15)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-42b06ad21152> in <cell line: 4>()
#       2
#       3 plt.figure(figsize=(12,8))
# ----> 4 sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[1])
#       5 plt.ylabel('Number of Occurrences', fontsize=12)
#       6 plt.xlabel('Eval set type', fontsize=12)
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
sample_submission_df = pd.read_csv("/content/drive/MyDrive/ESAA/sample_submission.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-f936b80043b0> in <cell line: 1>()
# ----> 1 sample_submission_df = pd.read_csv("/content/drive/MyDrive/ESAA/sample_submission.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# %matplotlib inline

pd.options.mode.chained_assignment = None  # default='warn'

# %%
from subprocess import check_output

# Google Drive에 있는 파일 리스트 출력
print(check_output(["ls", "/content/drive/MyDrive/ESAA"]).decode("utf8"))
# Out:
# aisles.csv
# departments.csv
# getting_and_knowing_occupation_Exercises_.ipynb
# order_products__prior.csv
# order_products__train.csv
# orders.csv
# products.csv

# %%
order_products_train_df = pd.read_csv("/content/drive/MyDrive/ESAA/order_products__train.csv")
order_products_prior_df = pd.read_csv("/content/drive/MyDrive/ESAA/order_products__prior.csv")
orders_df = pd.read_csv("/content/drive/MyDrive/ESAA/orders.csv")
products_df = pd.read_csv("/content/drive/MyDrive/ESAA/products.csv")
aisles_df = pd.read_csv("/content/drive/MyDrive/ESAA/aisles.csv")
departments_df = pd.read_csv("/content/drive/MyDrive/ESAA/departments.csv")

# %%
orders_df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
order_products_prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
order_products_train_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# eval_set의 값 빈도 계산
cnt_srs = orders_df.eval_set.value_counts()

# 그래프 그리기
plt.figure(figsize=(12, 8))
sns.barplot(x=cnt_srs.index, y=cnt_srs.values, alpha=0.8, color="green")
plt.title('Count of rows in each dataset')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Eval set type', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

# %%
def get_unique_count(x):
    return len(np.unique(x))

cnt_srs = orders_df.groupby("eval_set")["user_id"].aggregate(get_unique_count)
cnt_srs
# Out:
# eval_set
# prior    206209
# test      75000
# train    131209
# Name: user_id, dtype: int64

# %%
cnt_srs = orders_df.groupby("user_id")["order_number"].aggregate(np.max).reset_index()
cnt_srs = cnt_srs.order_number.value_counts()

plt.figure(figsize=(12,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[2])
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Maximum order number', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# <ipython-input-40-b69202b7f70a>:1: FutureWarning: The provided callable <function max at 0x78c1a170f9a0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   cnt_srs = orders_df.groupby("user_id")["order_number"].aggregate(np.max).reset_index()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-b69202b7f70a> in <cell line: 5>()
#       3
#       4 plt.figure(figsize=(12,8))
# ----> 5 sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[2])
#       6 plt.ylabel('Number of Occurrences', fontsize=12)
#       7 plt.xlabel('Maximum order number', fontsize=12)
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given
